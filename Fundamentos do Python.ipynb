# %% [markdown]
# <a href="https://colab.research.google.com/github/AriadneCavilha/AriadneCavilha/blob/main/Fundamentos%20do%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome =  'Ariadne'  # String
idade = 47 # Float
mensagem = 'Bom dia' # String
altura = 1.78
professor = True # Boolean

print(type(nome))
print(type(idade))
print(type(altura))
print(type(mensagem))
print(type(professor))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
nome = input('Digite o seu nome: ')
idade = input('Digite a sua idade: ')
fruta_favorita = input('Qual é a sua fruta favorita? ')
print(f'Olá {nome}, você tem {idade} anos de idade e a sua fruta favorita é {fruta_favorita}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_681/1694497489.py in <cell line: 0>()
# ----> 1 nome = input('Digite o seu nome: ')
#       2 idade = input('Digite a sua idade: ')
#       3 fruta_favorita = input('Qual é a sua fruta favorita? ')
#       4 print(f'Olá {nome}, você tem {idade} anos de idade e a sua fruta favorita é {fruta_favorita}')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
nome = input('Digite o seu nome: ')
idade = int(input('Digite a sua idade: '))

print(f'Olá {nome}, daqui 5 anos você terá {idade + 5} de idade')

# %%
num1 = 10
num2 = 2

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2) ## resto da divisão
print(num1 ** num2)

# %%
preco = 50 ## em reais
desconto = 10 ## em porcentagem

preco_com_desconto = preco * (1 - desconto / 100)
print(preco_com_desconto)

print(f'O valor com desconto é de {preco_com_desconto} reais' )

# %%
preco = int(input('Digite o valor do produto: '))
desconto = int(input('Digite o desconto a ser aplicado: '))

preco_com_desconto = preco * (1 - desconto / 100)
print(preco_com_desconto)

print(f'O valor com desconto é de {preco_com_desconto} reais' )

# %%
## Calcular quantos dias um produto duraria se a pessoa usar X porções por dia
quantidade_produto = int(input("Digite a quantidade do seu produto: "))
quantidade_diaria = int(input("Qual a porção que você vai usar por dia: "))

dias = quantidade_produto / quantidade_diaria
print(f'O seu produto vai durar cerca de {dias:.0f} dias')

# %%
num1 = 11
num2 = 11
print(num1 != num2)
print(num1 >= num2)

idade = int(input('Digite a sua idade: '))
if(idade >= 18):
  print("Você é maior de idade")
else:
  print("Você é menor de idade")

  ## Para digirir a pessoa tem que ser maior de idade e ter carteira de motorista
idade = int(input('Digite a sua idade: '))
carteira = False
verificador = idade >= 18 or carteira
print(verificador)

# %%
usuario = input('Digite o seu usuário: ')
senha = input('Digite a sua senha: ')

login_valido = usuario == 'Admin' and senha == '123admin'
print(f'Login permitido: {login_valido}')

# %%
nota_aluno = float(input('Qual foi a sua nota no exame? '))

if nota_aluno >= 7:
  print('Você foi aprovado')
elif nota_aluno >= 5:
  print('Você pegou exame')
else:
  print('Você foi reprovado')

# %%
for i in range(5, 0, -1):
  print(i)

# %%
i = 0
while i < 5:
  print(i)
  i += 1

# %%
senha = ''
while(senha != '1234'):
  senha = input('Digite a sua senha: ')
print('Acesso permitido')

# %%
frutas = ['Maça', 'Banana', 'Morango']

frutas.append('Uva')
frutas.append('Laranja')
frutas.remove('Banana')

print(frutas[0])
print(frutas)

# %%
## LISTAS
tarefas = []

tarefas.append('Estudar Python com IA')
tarefas.append('Ler um artigo sobre IA')
tarefas.append('Responder emails')

print('Minhas tarefas diárias:')
for i in range(len(tarefas)):
  print(tarefas[i])

# %%
##TUPLAS
meses = ('Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro')

print(meses)

# %%
usuario = {
    'nome': 'Andre',
    'idade': '47',
    'Departamento': 'TI'
}

print(usuario['nome'])
# Out:
# Andre

# %%
##DICIONÁRIOS
aluno = {
    'nome': input('Nome do Aluno:'),
    'idade': input('Idade do Aluno: '),
    'nota': input('Nota do Aluno: ')
}

print(f'{aluno['nome']} tem {aluno['idade']} anos de idade e tirou uma nota de {aluno['nota']}')
# Out:
# Nome do Aluno:Ari
# Idade do Aluno: 22
# Nota do Aluno: 10
# Ari tem 22 anos de idade e tirou uma nota de 10

# %%
## FUNÇÕES
def saudacao():
  print('Olá')

saudacao()

def saudacao(nome):
  print(f'Olá, {nome}')

saudacao(input('Digite o seu nome: '))

def saudacao(nome, idade):
  print(f'Olá, {nome} você tem {idade} anos de idade')

saudacao('Ari', 10)
# Out:
# Olá
# Digite o seu nome: Ari
# Olá, Ari
# Olá, Ari você tem 10 anos de idade

# %%
def somar(num1, num2):
  return num1 + num2

total = somar(4, 10)
print(f'O resultado da soma é de {total}')
# Out:
# O resultado da soma é de 14

# %%
def calcular_desconto(preco, porcentagem):
  return preco  - (preco * porcentagem / 100)

final = calcular_desconto(1010, 25)
print(f'O valor final com desconto é de: {final:.2f} reais')
# Out:
# O valor final com desconto é de: 757.50 reais

# %%
import importlib
import funcoes
importlib.reload(funcoes)

print(funcoes.soma(2, 10))

minha_idade = int(input('Digite a sua idade: '))

if(funcoes.verificar_maioridade(minha_idade)):
  print('Você é maior de idade :)')
else:
  print('Você é menor de idade')
# Out:
# 12
# Digite a sua idade: 22
# Você é maior de idade :)
